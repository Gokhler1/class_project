# %%
import pandas as pd

# %%
destination = 'C:/Users/z003vhmu/Desktop/RUTSOM201810DATA5-master/yelp_academic_dataset_business.json'
destination_income = 'C:/Users/z003vhmu/Desktop/RUTSOM201810DATA5-master/income per zip code.csv.csv'
df = pd.read_json(destination, lines=True)

# View the first ten rows
df.head(5)
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# ...

# %%
# df.to_csv('C:/Users/z003vhmu/Desktop/RUTSOM201810DATA5-master/categories.csv')

# %%
# # get uniuqe category values 
# categories = df['categories']
# unique_categories=[]

# unique_categories.append(categories.str.split(", "))

# flat_set=set()
# try:
#   for sublist in unique_categories:
#     for sublist2 in sublist:
#         for item in sublist2:
#             flat_set.add(item)
# except TypeError:
#   print("found an issue")

# unique_categories_df = pd.DataFrame(flat_set)
# unique_categories_df.to_csv('C:/Users/z003vhmu/Desktop/RUTSOM201810DATA5-master/unique_categories.csv')
# # flat_set

# # len(flat_set )   
# #unique_categories

# %%
# get uniuqe category values 
categories = df['categories']
unique_categories=[]

unique_categories.append(categories.str.split(", "))

flat_set=[]
try:
  for sublist in unique_categories:
    for sublist2 in sublist:
        for item in sublist2:
            flat_set.append(item)
except TypeError:
  print("found an issue")

unique_categories_df = pd.DataFrame(flat_set)
# unique_categories_df.to_csv('C:/Users/z003vhmu/Desktop/RUTSOM201810DATA5-master/unique_categories.csv')
# flat_set

# len(flat_set )   
#unique_categories
# Out:
# found an issue

# %%
df['mexican_identifier'] = df['categories'].str.contains('Mexican', regex=False)
mexican = df.loc[df['mexican_identifier'] == True]

# %%
mexican.head(5)
# Out:
#                            address  \
# 11         2450 E Indian School Rd
# 25           6055 E Lake Mead Blvd
# 96             1614 Queen Street E
# 146       3140 S Gilbert Rd, Ste 3
# 156  1770 W Horizon Ridge, Ste 100
#
#                                             attributes  \
# 11   {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 25   {'BikeParking': 'True', 'BusinessParking': '{'...
# 96   {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 146  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 156  {'DriveThru': 'False', 'RestaurantsAttire': ''...
#
#                 business_id  \
# 11   1Dfx3zM-rW4n-31KeC8sJg
# 25   tstimHoMcYbkSC4eBA1wEg
# 96   NPHZkn1e-tSJAbo8Zm9rYw
# 146  voZnDQs6Hs3YpNcS-9TALg
# 156  jScBTQtdAt-8RshaiBEHgw
#
#                                             categories       city  \
# 11   Restaurants, Breakfast & Brunch, Mexican, Taco...    Phoenix
# 25   Mexican, Restaurants, Patisserie/Cake Shop, Fo...  Las Vegas
# ...

# %%
mexican.loc[mexican['postal_code'] == "75002"]
# Out:
# Empty DataFrame
# Columns: [address, attributes, business_id, categories, city, hours, is_open, latitude, longitude, name, postal_code, review_count, stars, state, mexican_identifier]
# Index: []

# %%
average_mexican= mexican.groupby(['postal_code'], as_index=False).mean()
average_mexican.head()
# Out:
#   postal_code   is_open   latitude  longitude  review_count  stars
# 0              0.714286  39.022148 -95.153161          17.0    3.5
# 1       12979  1.000000  44.983355 -73.363455           4.0    4.5
# 2       15003  1.000000  40.587920 -80.224920           9.0    3.5
# 3       15017  1.000000  40.371443 -80.102629          22.8    3.0
# 4       15035  1.000000  40.382997 -79.810277          14.0    4.5

# %%
# count_mexican= mexican.groupby(['city','postal_code']).count()
# count_mexican.head(5)

# %%
# average_mexican= mexican.groupby(['city']).mean().sort_values(by=['stars'])
# average_mexican.head(5)

# %%
destination_income = 'C:/Users/z003vhmu/Desktop/RUTSOM201810DATA5-master/household_income_data.csv'
df_income = pd.read_csv(destination_income)
df_income.head(5)
# Out:
#     State_Name State_ab               County       City        Place  \
# 0  Puerto Rico       PR   Adjuntas Municipio   Adjuntas     Adjuntas
# 1  Puerto Rico       PR   Adjuntas Municipio     Aguada     Adjuntas
# 2  Puerto Rico       PR   Adjuntas Municipio  Aguadilla     Adjuntas
# 3  Puerto Rico       PR  Aguadilla Municipio  Aguadilla  San Antonio
# 4  Puerto Rico       PR   Adjuntas Municipio    Maricao     Adjuntas
#
#         Type Primary  Zip_Code  Area_Code     ALand  AWater        Lat  \
# 0      Track   Track       601        787  44833906   90659  18.204166
# 1      Track   Track       602        787   1801613  795887  18.385424
# 2      Track   Track       603        787  38303170    3440  18.424622
# 3  Community   place       605        787   1252042    1016  18.492693
# 4      Track   Track       606        787  10379871       0  18.192187
#
#          Lon   Mean    Median    Stdev        sum_w
# 0 -66.737830   19807      9378    21654  524.345149
# ...

# %%
df_income.rename(columns={"Zip_Code":"postal_code"}, inplace=True)
df_income.head(5)
# Out:
#     State_Name State_ab               County       City        Place  \
# 0  Puerto Rico       PR   Adjuntas Municipio   Adjuntas     Adjuntas
# 1  Puerto Rico       PR   Adjuntas Municipio     Aguada     Adjuntas
# 2  Puerto Rico       PR   Adjuntas Municipio  Aguadilla     Adjuntas
# 3  Puerto Rico       PR  Aguadilla Municipio  Aguadilla  San Antonio
# 4  Puerto Rico       PR   Adjuntas Municipio    Maricao     Adjuntas
#
#         Type Primary  postal_code  Area_Code     ALand  AWater        Lat  \
# 0      Track   Track          601        787  44833906   90659  18.204166
# 1      Track   Track          602        787   1801613  795887  18.385424
# 2      Track   Track          603        787  38303170    3440  18.424622
# 3  Community   place          605        787   1252042    1016  18.492693
# 4      Track   Track          606        787  10379871       0  18.192187
#
#          Lon   Mean    Median    Stdev        sum_w
# 0 -66.737830   19807      9378    21654  524.345149
# ...

# %%
df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14776 entries, 0 to 14775
# Data columns (total 17 columns):
# State_Name     14776 non-null object
# State_ab       14776 non-null object
# County         14776 non-null object
# City           14776 non-null object
# Place          14776 non-null object
# Type           14776 non-null object
# Primary        14776 non-null object
# postal_code    14776 non-null object
# Area_Code      14776 non-null int64
# ALand          14776 non-null int64
# AWater         14776 non-null int64
# Lat            14776 non-null float64
# Lon            14776 non-null float64
#  Mean          14776 non-null int64
#  Median        14776 non-null int64
#  Stdev         14776 non-null int64
# sum_w          14776 non-null float64
# dtypes: float64(3), int64(6), object(8)
# memory usage: 1.9+ MB

# %%
average_mexican.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 993
# Data columns (total 6 columns):
# postal_code     994 non-null object
# is_open         994 non-null float64
# latitude        994 non-null float64
# longitude       994 non-null float64
# review_count    994 non-null float64
# stars           994 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 54.4+ KB

# %%
# to change use .astype() 
df_income['postal_code'] = df_income.postal_code.astype(object)

# %%
df_income
# Out:
#         State_Name State_ab                             County  \
# 0      Puerto Rico       PR                 Adjuntas Municipio
# 1      Puerto Rico       PR                 Adjuntas Municipio
# 2      Puerto Rico       PR                 Adjuntas Municipio
# 3      Puerto Rico       PR                Aguadilla Municipio
# 4      Puerto Rico       PR                 Adjuntas Municipio
# 5      Puerto Rico       PR                 Adjuntas Municipio
# 6      Puerto Rico       PR                 Adjuntas Municipio
# 7      Puerto Rico       PR                 Adjuntas Municipio
# 8      Puerto Rico       PR                 Adjuntas Municipio
# 9      Puerto Rico       PR                 Adjuntas Municipio
# 10     Puerto Rico       PR                 Adjuntas Municipio
# 11     Puerto Rico       PR                 Adjuntas Municipio
# 12     Puerto Rico       PR                 Adjuntas Municipio
# 13     Puerto Rico       PR            Sabana Grande Municipio
# ...

# %%
a = pd.merge(df_income, average_mexican,on='postal_code',how='left')
a[a.stars.notnull()]
# Out:
# Empty DataFrame
# Columns: [State_Name, State_ab, County, City, Place, Type, Primary, postal_code, Area_Code, ALand, AWater, Lat, Lon,  Mean ,  Median ,  Stdev , sum_w, is_open, latitude, longitude, review_count, stars]
# Index: []
#
# [0 rows x 22 columns]

# %%
joined_
